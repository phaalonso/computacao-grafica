# %%
import numpy as np
import matplotlib.pyplot as plt
from plot_helper import *

# %%
# definindo a matriz de transformação A
matrizA = np.array([[2, 1], [1, 2]])

# %%
print(matrizA)
# Out:
# [[2 1]
#  [1 2]]

# %%
plot_linear_transformation(matrizA)
